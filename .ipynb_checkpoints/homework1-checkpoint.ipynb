# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import operator

# %%
# read csv file
df = pd.read_csv("housing.header.txt")
df.head()
# Out:
#       Crim    Zn  Indus  Chas    Nox     Rm   Age     Dis  Rad  Tax  Ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  Lstat  Medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# 8.1
# Report all samples with respect to the Crim index on a plot 
# (the x-axis show the index of the sample, and the y-axis shows the crim index of the sample). 
x = df.index
y = df[["Crim"]]
plt.plot(x,y)
plt.xlabel('Crim')
plt.ylabel('Index')
plt.show()

# %%
# 8.2
# Show both histogram of the Crim index and the density of the Crim index on a 1x2 frame. 

fig, axes = plt.subplots(nrows=1, ncols=2)

x = df[["Crim"]]

sns.distplot(x, hist=True, kde=False, bins=20, color = 'blue',hist_kws={'edgecolor':'black'}, ax=axes[0])
axes[0].set_title("Histogram")

sns.distplot(x, hist=False, kde=True, bins=20, color = 'blue', ax=axes[1])
axes[1].set_title("Density")
axes[1].set_ylabel("")

fig.tight_layout()
# Out:
# c:\users\milind.desktop-gbr1bs2\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\milind.desktop-gbr1bs2\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# 8.3
# Show following four scatter plots in one frame (1x4), 
# crim-medv, Rm-medv, Age-medv,Tax-medv, 
# and explain how are they (Crim, Rm, Age, Tax) correlated to the medium house value (Medv)

fig, axes = plt.subplots(1,4)

axes[0].scatter(df[["Crim"]],df[["Medv"]])
axes[0].set_title("Crim - Medv")

axes[1].scatter(df[["Rm"]],df[["Medv"]])
axes[1].set_title("Rm - Medv")

axes[2].scatter(df[["Age"]],df[["Medv"]])
axes[2].set_title("Age - Medv")

axes[3].scatter(df[["Tax"]],df[["Medv"]])
axes[3].set_title("Tax - Medv")

fig.tight_layout()
plt.show()

# %%
# 8.4
# Create a subset which only includes properties with Crim less than 1 (inclusive), and Rm greater than 6 (inclusive).
df_subset = df[(df["Crim"] <= 1) & (df["Rm"] >= 6)]
print(df_subset.shape)
df_subset.head()
# Out:
# (236, 14)
#       Crim    Zn  Indus  Chas    Nox     Rm   Age     Dis  Rad  Tax  Ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  Lstat  Medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# 8.5
# Show a scatter plot between Rm and Medv (x-axis shows Rm and y-axis denote Medv), 
# please color all properties with 7 or larger Rm values as “red”, and rest properties as “black”

colors = np.where(df[["Rm"]] >= 7, 'r', 'black').flatten()
plt.scatter(df[["Rm"]],df[["Medv"]], c=colors)
plt.xlabel('Rm')
plt.ylabel('Medv')
plt.show()

# %%
# 8.6
# Report the pairwise correlation between every two variables (either as a matrix or as a level plot) 

plt.figure(figsize=(20,15))
plt.matshow(df.corr(),fignum=1,aspect='auto')
plt.xticks(range(len(df.columns)), df.columns)
plt.yticks(range(len(df.columns)), df.columns)
plt.colorbar()
plt.show()

# %%
# 8.7
# Please explain which variable is mostly positively correlated to Medv (medium house value), 
# and which variable is mostly negatively correlated to Medv.

print('''From the above plot, right most column indicates the correlation between Medv & other features.
Color close to darker blue indicates, negative correlation and color colser to yellow indicates postive correlation
Negative correlated features: Lstat, Ptatio, Crim, Tax, Indus, Rad, Age
Positive correlated features: Rm, B, Dis, Chas''')
# Out:
# From the above plot, right most column indicates the correlation between Medv & other features.
# Color close to darker blue indicates, negative correlation and color colser to yellow indicates postive correlation
# Negative correlated features: Lstat, Ptatio, Crim, Tax, Indus, Rad, Age
# Positive correlated features: Rm, B, Dis, Chas

# %%
# 8.8
# Draw scatterplots to show relationship between each attribute and Medv, respectively.

fig, axes = plt.subplots(3,5, figsize=(12, 9))
i = 0
j = 0

for col in df.columns:
    if col != "Medv":    
        axes[i,j].scatter(df[[col]],df[["Medv"]])
        axes[i,j].set_xlabel(col)
        axes[i,j].set_ylabel('Medv')
        j += 1
        if j == 5 :
            i += 1
            j = 0

axes[-1,-1].axis("off")
axes[-1,-2].axis("off")

fig.tight_layout()
plt.show()

# %%
# 8.9
# Explain how to use scatterplots to find attributes which are positively correlated, negatively correlated, 
# or independent of Medv, respectively

print("Following features NEGATIVELY correlated to Medv: ")
print("Crim \nNox \nAge \nDis \nTax \nPtratio \nLstat")

print("\n\nFollowing features POSITVELY correlated to Medv: ")
print("Indus \nRm \nB")

print("\n\nFollowing features INDEPENDENT of Medv: ")
print("Zn \nChas \nRad")
# Out:
# Following features NEGATIVELY correlated to Medv:
# Crim
# Nox
# Age
# Dis
# Tax
# Ptratio
# Lstat
#
#
# Following features POSITVELY correlated to Medv:
# Indus
# Rm
# B
#
#
# Following features INDEPENDENT of Medv:
# Zn
# Chas
# Rad

# %%
# 9.1
# Read the movie100.csv, and check average length (in terms of number of words) of the positive 
# and negative reviews, respectively

movies = pd.read_csv("review100.csv")
positives_reviews = movies.loc[movies["sentiment"] == "positive", ["movie review"]]
positives = positives_reviews["movie review"].str.split().str.len()
positive_avg_words = positives.mean()
print("Positive review average words count: ", positive_avg_words)

negatives_reviews = movies.loc[movies["sentiment"] == "negative", ["movie review"]]
negatives = negatives_reviews["movie review"].str.split().str.len()
negatives_avg_words = negatives.mean()
print("Negative review average words count: ", negatives_avg_words)
# Out:
# Positive review average words count:  271.58
# Negative review average words count:  201.86

# %%
# 9.2
# Check the frequency of the words with respect to positive and negative reviews, respectively. 
# Print the top 20 most frequent words (including words and their frequency), 
# for positive and negative reviews, respectively

positive_words = dict()
for index, row in positives_reviews.iterrows():
    for word in row["movie review"].split():
        if word not in positive_words:
            positive_words[word] = 1
        else:
            positive_words[word] = positive_words[word]+1
            
negative_words = dict()         
for index, row in negatives_reviews.iterrows():
    for word in row["movie review"].split():
        if word not in negative_words:
            negative_words[word] = 1
        else:
            negative_words[word] = negative_words[word]+1
            
positive_top_20 = dict(sorted(positive_words.items(), key=operator.itemgetter(1),reverse=True)[:20])
print("Top 20 words in Positive reviews:")
print(positive_top_20)

negative_top_20 = dict(sorted(negative_words.items(), key=operator.itemgetter(1),reverse=True)[:20])
print("\n\nTop 20 words in Negative reviews:")
print(negative_top_20)
# Out:
# Top 20 words in Positive reviews:
# {'the': 738, 'and': 381, 'of': 370, 'a': 342, 'to': 303, 'is': 268, 'in': 227, '/><br': 126, 'that': 125, 'as': 109, 'his': 103, 'with': 102, 'it': 100, 'for': 93, 'this': 86, 'I': 84, 'was': 79, 'he': 72, 'by': 72, 'on': 70}
#
#
# Top 20 words in Negative reviews:
# {'the': 521, 'a': 286, 'to': 249, 'and': 245, 'of': 244, 'is': 167, 'in': 143, 'I': 127, 'this': 107, 'was': 106, 'that': 103, '/><br': 99, 'it': 92, 'for': 70, 'with': 69, 'but': 67, 'movie': 65, 'The': 65, 'have': 58, 'not': 53}

# %%
# 9.3
# Draw a bar plot to show the frequency of the two-20 most frequent words 
# (the x-axis denotes words, and the y-axis denotes their frequency), for positive and negative reviews, respectively

fig, axes = plt.subplots(1,2, figsize=(25, 15))


fig = plt.figure()
axes[0].bar(list(positive_top_20.keys()), list(positive_top_20.values()))
axes[0].set_title("Top 20 Positive review words")

axes[1].bar(list(negative_top_20.keys()), list(negative_top_20.values()), color='r')
axes[1].set_title("Top 20 Negative review words")

fig.tight_layout()
plt.show()
